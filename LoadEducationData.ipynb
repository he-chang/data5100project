# %%
import pandas as pd
import numpy as np

years = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
files = ['gr{}_rv.csv', 'ef{}a_rv.csv', 'hd{}.csv']
#files = ['adm{}_rv.csv', 'c{}_a_rv.csv', 'ef{}a_rv.csv', 'gr{}_rv.csv', 'hd{}.csv', 's{}_oc_rv.csv']

# %%
# Get all the dataframes into a dictionary
dataframes = {'university_data': [], 'enrollment_data': [], 'graduation_data': []}

for f in files:
    for y in years:
        data = pd.read_csv("C:\\project\\{}\\{}".format(y, f.format(y)), encoding = 'ISO-8859-1')
        data['year'] = int(y)
        
        if f[0] == 'h':
            dataframes['university_data'].append(data)
        elif f[0] == 'e':
            dataframes['enrollment_data'].append(data)
        elif f[0] == 'g':
            dataframes['graduation_data'].append(data)

# %%
# Merge the data frames into one dataframe per category
unv_df = dataframes['university_data'][0]
enr_df = dataframes['enrollment_data'][0]
grad_df = dataframes['graduation_data'][0]

for key in dataframes.keys():
    df_list = dataframes[key]
    count = 0

    for l_item in df_list:

        if count == 0:
            count += 1
            continue
        else:
            if key == 'university_data':
                unv_df = pd.concat([unv_df, l_item])
            elif key == 'enrollment_data':
                enr_df = pd.concat([enr_df, l_item])
            elif key == 'graduation_data':
                grad_df = pd.concat([grad_df, l_item])
        
        count += 1

# %%
#school_data = pd.read_csv("C:\\project\\2014\\adm2014.csv", encoding = 'ISO-8859-1')
# Grab Washington Schools only
wa_unv_df = unv_df[(unv_df['STABBR'] == 'WA') & (unv_df['ICLEVEL'] == 1) & (unv_df['HLOFFER'].isin([5,6,7,8,9]))][['UNITID', 'INSTNM', 'STABBR', 'ICLEVEL', 'year']]
wa_unv_df
# Out:
#       UNITID                                             INSTNM STABBR  \
# 4331  234492                       The Art Institute of Seattle     WA
# 4333  234669                                   Bellevue College     WA
# 4339  234827                      Central Washington University     WA
# 4341  234915                         City University of Seattle     WA
# 4345  234979                             Columbia Basin College     WA
# ...      ...                                                ...    ...
# 4707  443410                    DigiPen Institute of Technology     WA
# 5122  455406    Pacific Northwest University of Health Sciences     WA
# 5496  475200         Whitworth University-Adult Degree Programs     WA
# 5960  487603  Northwest University-College of Adult and Prof...     WA
# 6016  488448                             Seattle Film Institute     WA
#
#       ICLEVEL  year
# 4331        1  2010
# 4333        1  2010
# 4339        1  2010
# 4341        1  2010
# 4345        1  2010
# ...       ...   ...
# 4707        1  2020
# 5122        1  2020
# 5496        1  2020
# 5960        1  2020
# 6016        1  2020
#
# [652 rows x 5 columns]

# %%
wa_enr_df = enr_df[enr_df['UNITID'].isin(wa_unv_df['UNITID'])].copy()
wa_cohort_df = enr_df[enr_df['UNITID'].isin(wa_unv_df['UNITID'])].copy()

# %%
# rename variables to something that we can understand better
wa_enr_df = wa_enr_df.rename(columns={'UNITID': 'institute_id',
                       'EFALEVEL': 'student_lvl',
                       'LINE': 'student_lvl_og',
                       'SECTION': 'attend_status',
                       'LSTUDY': 'student_lvl_2',
                       'EFTOTLT': 'e_total',
                       'EFTOTLM': 'e_total_m',
                       'EFTOTLW': 'e_total_w',
                       'EFAIANT': 'e_AmerInd_AlaskNtv',
                       'EFAIANM': 'e_AmerInd_AlaskNtv_m',
                       'EFAIANW': 'e_AmerInd_AlaskNtv_w',
                       'EFASIAT': 'e_Asian',
                       'EFASIAM': 'e_Asian_m',
                       'EFASIAW': 'e_Asian_w',
                       'EFBKAAT': 'e_AfrAmer',
                       'EFBKAAM': 'e_AfrAmer_m',
                       'EFBKAAW': 'e_AfrAmer_w',
                       'EFHISPT': 'e_Hispanic',
                       'EFHISPM': 'e_Hispanic_m',
                       'EFHISPW': 'e_Hispanic_w',
                       'EFNHPIT': 'e_Hi_PacIsland',
                       'EFNHPIM': 'e_Hi_PacIsland_m',
                       'EFNHPIW': 'e_Hi_PacIsland_w',
                       'EFWHITT': 'e_White',
                       'EFWHITM': 'e_White_m',
                       'EFWHITW': 'e_White_w',
                       'EF2MORT': 'e_2orMore',
                       'EF2MORM': 'e_2orMore_m',
                       'EF2MORW': 'e_2orMore_w',
                       'EFUNKNT': 'e_unknown',
                       'EFUNKNM': 'e_unknown_m',
                       'EFUNKNW': 'e_unknown_w',
                       'EFNRALT': 'e_nonresAlien',
                       'EFNRALM': 'e_nonresAlien_m',
                       'EFNRALW ': 'e_nonresAlien_w'
                       })

# %%
wa_enr_df = wa_enr_df[wa_enr_df['institute_id'].isin(wa_unv_df['UNITID'])]
df_enrollment = wa_enr_df[wa_enr_df['student_lvl'] == 1][['institute_id', 'e_total', 'e_AmerInd_AlaskNtv', 'e_Asian', 'e_AfrAmer', 'e_Hispanic', 'e_Hi_PacIsland', 'e_White', 'e_2orMore', 'e_unknown', 'e_nonresAlien', 'year']].groupby(['institute_id', 'year']).sum()

# %%
# rename variables to something that we can understand better
wa_cohort_df = wa_cohort_df.rename(columns={'UNITID': 'institute_id',
                       'EFALEVEL': 'student_lvl',
                       'LINE': 'student_lvl_og',
                       'SECTION': 'attend_status',
                       'LSTUDY': 'student_lvl_2',
                       'EFTOTLT': 'co_total',
                       'EFTOTLM': 'co_total_m',
                       'EFTOTLW': 'co_total_w',
                       'EFAIANT': 'co_AmerInd_AlaskNtv',
                       'EFAIANM': 'co_AmerInd_AlaskNtv_m',
                       'EFAIANW': 'co_AmerInd_AlaskNtv_w',
                       'EFASIAT': 'co_Asian',
                       'EFASIAM': 'co_Asian_m',
                       'EFASIAW': 'co_Asian_w',
                       'EFBKAAT': 'co_AfrAmer',
                       'EFBKAAM': 'co_AfrAmer_m',
                       'EFBKAAW': 'co_AfrAmer_w',
                       'EFHISPT': 'co_Hispanic',
                       'EFHISPM': 'co_Hispanic_m',
                       'EFHISPW': 'co_Hispanic_w',
                       'EFNHPIT': 'co_Hi_PacIsland',
                       'EFNHPIM': 'co_Hi_PacIsland_m',
                       'EFNHPIW': 'co_Hi_PacIsland_w',
                       'EFWHITT': 'co_White',
                       'EFWHITM': 'co_White_m',
                       'EFWHITW': 'co_White_w',
                       'EF2MORT': 'co_2orMore',
                       'EF2MORM': 'co_2orMore_m',
                       'EF2MORW': 'co_2orMore_w',
                       'EFUNKNT': 'co_unknown',
                       'EFUNKNM': 'co_unknown_m',
                       'EFUNKNW': 'co_unknown_w',
                       'EFNRALT': 'co_nonresAlien',
                       'EFNRALM': 'co_nonresAlien_m',
                       'EFNRALW ': 'co_nonresAlien_w'
                       }).copy()

# %%
wa_cohort_df = wa_cohort_df[wa_cohort_df['institute_id'].isin(wa_unv_df['UNITID'])]
df_cohort = wa_cohort_df[wa_cohort_df['student_lvl'] == 24][['institute_id', 'co_total', 'co_AmerInd_AlaskNtv', 'co_Asian', 'co_AfrAmer', 'co_Hispanic', 'co_Hi_PacIsland', 'co_White', 'co_2orMore', 'co_unknown', 'co_nonresAlien', 'year']].groupby(['institute_id', 'year']).sum()
df_cohort
# Out:
#                    co_total  co_AmerInd_AlaskNtv  co_Asian  co_AfrAmer  \
# institute_id year
# 102845       2010      1658                  109        40         102
#              2011       871                   45        15          24
#              2012       918                   54        63          42
#              2013      1053                   49        16          57
#              2014       437                   34         3          25
# ...                     ...                  ...       ...         ...
# 488448       2016         6                    0         0           0
#              2017         9                    0         0           1
#              2018         7                    0         0           0
#              2019         8                    0         0           1
#              2020         9                    0         1           1
#
#                    co_Hispanic  co_Hi_PacIsland  co_White  co_2orMore  \
# institute_id year
# 102845       2010          440               39       639          19
#              2011          267               17       323          16
#              2012          282               10       387          45
#              2013          316               73       451          68
#              2014          156               25       158          16
# ...                        ...              ...       ...         ...
# 488448       2016            1                0         5           0
#              2017            1                0         7           0
#              2018            1                0         6           0
#              2019            2                0         5           0
#              2020            2                0         5           0
#
#                    co_unknown  co_nonresAlien
# institute_id year
# 102845       2010         175              95
#              2011         124              40
#              2012          35               0
#              2013          23               0
#              2014          20               0
# ...                       ...             ...
# 488448       2016           0               0
#              2017           0               0
#              2018           0               0
#              2019           0               0
#              2020           0               0
#
# [656 rows x 10 columns]

# %%
wa_grad_df = grad_df[grad_df['UNITID'].isin(wa_unv_df['UNITID'])]
wa_grad_df
# Out:
#        UNITID  GRTYPE  CHRTSTAT  SECTION  COHORT XGRNRALM  GRNRALM XGRNRALW  \
# 636    102845       2        12        1       1        Z      0.0        Z
# 637    102845       3        13        1       1        Z      0.0        Z
# 638    102845       6        10        2       2        R      0.0        R
# 639    102845       8        12        2       2        R      0.0        R
# 640    102845       9        13        2       2        R      0.0        R
# ...       ...     ...       ...      ...     ...      ...      ...      ...
# 49371  488448      20        12        3       3        R      0.0        R
# 49372  488448      21        13        3       3        R      0.0        R
# 49373  488448      22        14        3       3        R      0.0        R
# 49374  488448      42        32        1       1        R      0.0        R
# 49375  488448      46        32        3       3        R      0.0        R
#
#        GRNRALW XGRRAC03  ...  DVGRHSW XDVGRWHT  DVGRWHT XDVGRWHM  DVGRWHM  \
# 636        0.0        R  ...      3.0        R     13.0        R      8.0
# 637        0.0        R  ...      3.0        R     13.0        R      8.0
# 638        0.0        R  ...      0.0        R      3.0        R      3.0
# 639        0.0        R  ...      0.0        R      3.0        R      3.0
# 640        0.0        R  ...      0.0        R      3.0        R      3.0
# ...        ...      ...  ...      ...      ...      ...      ...      ...
# 49371      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 49372      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 49373      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 49374      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
# 49375      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
#
#       XDVGRWHW  DVGRWHW   year  LINE GRNRALW
# 636          R         5  2010   NaN      NaN
# 637          R         5  2010   NaN      NaN
# 638          R         0  2010   NaN      NaN
# 639          R         0  2010   NaN      NaN
# 640          R         0  2010   NaN      NaN
# ...        ...       ...   ...   ...      ...
# 49371      NaN       NaN  2020   50       0.0
# 49372      NaN       NaN  2020   29A      0.0
# 49373      NaN       NaN  2020   11A      0.0
# 49374      NaN       NaN  2020   999      0.0
# 49375      NaN       NaN  2020   23       0.0
#
# [8502 rows x 128 columns]

# %%
# rename variables to something that we can understand better
wa_grad_df = wa_grad_df.rename(columns={'UNITID': 'institute_id',
                       'COHORT':  'cohort',
                       'GRTOTLT': 'gr_total',
                       'GRAIANT': 'gr_AmerInd_AlaskNtv',
                       'GRASIAT': 'gr_Asian',
                       'GRBKAAT': 'gr_AfrAmer',
                       'GRHISPT': 'gr_Hispanic',
                       'GRNHPIT': 'gr_Hi_PacIsland',
                       'GRWHITT': 'gr_White',
                       'GR2MORT': 'gr_2orMore',
                       'GRUNKNT': 'gr_unknown',
                       'GRNRALT': 'gr_nonresAlien'
                       })
wa_grad_df
# Out:
#        institute_id  GRTYPE  CHRTSTAT  SECTION  cohort XGRNRALM  GRNRALM  \
# 636          102845       2        12        1       1        Z      0.0
# 637          102845       3        13        1       1        Z      0.0
# 638          102845       6        10        2       2        R      0.0
# 639          102845       8        12        2       2        R      0.0
# 640          102845       9        13        2       2        R      0.0
# ...             ...     ...       ...      ...     ...      ...      ...
# 49371        488448      20        12        3       3        R      0.0
# 49372        488448      21        13        3       3        R      0.0
# 49373        488448      22        14        3       3        R      0.0
# 49374        488448      42        32        1       1        R      0.0
# 49375        488448      46        32        3       3        R      0.0
#
#       XGRNRALW  GRNRALW XGRRAC03  ...  DVGRHSW XDVGRWHT  DVGRWHT XDVGRWHM  \
# 636          Z      0.0        R  ...      3.0        R     13.0        R
# 637          Z      0.0        R  ...      3.0        R     13.0        R
# 638          R      0.0        R  ...      0.0        R      3.0        R
# 639          R      0.0        R  ...      0.0        R      3.0        R
# 640          R      0.0        R  ...      0.0        R      3.0        R
# ...        ...      ...      ...  ...      ...      ...      ...      ...
# 49371        R      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 49372        R      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 49373        R      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 49374        R      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 49375        R      NaN      NaN  ...      NaN      NaN      NaN      NaN
#
#        DVGRWHM XDVGRWHW  DVGRWHW   year  LINE GRNRALW
# 636        8.0        R         5  2010   NaN      NaN
# 637        8.0        R         5  2010   NaN      NaN
# 638        3.0        R         0  2010   NaN      NaN
# 639        3.0        R         0  2010   NaN      NaN
# 640        3.0        R         0  2010   NaN      NaN
# ...        ...      ...       ...   ...   ...      ...
# 49371      NaN      NaN       NaN  2020   50       0.0
# 49372      NaN      NaN       NaN  2020   29A      0.0
# 49373      NaN      NaN       NaN  2020   11A      0.0
# 49374      NaN      NaN       NaN  2020   999      0.0
# 49375      NaN      NaN       NaN  2020   23       0.0
#
# [8502 rows x 128 columns]

# %%
df_graduation = wa_grad_df[['institute_id', 'gr_total', 'gr_AmerInd_AlaskNtv', 'gr_Asian', 'gr_AfrAmer', 'gr_Hispanic', 'gr_Hi_PacIsland', 'gr_White', 'gr_2orMore', 'gr_unknown', 'gr_nonresAlien', 'year']].groupby(['institute_id', 'year']).sum()
df_graduation
# Out:
#                    gr_total  gr_AmerInd_AlaskNtv  gr_Asian  gr_AfrAmer  \
# institute_id year
# 102845       2010       167                  0.0       0.0         0.0
#              2011       191                 12.0      12.0         6.0
#              2012      1490                217.0     227.0       132.0
#              2013      4482                727.0     666.0       443.0
#              2014      3677                397.0     191.0       283.0
# ...                     ...                  ...       ...         ...
# 488448       2016        24                  0.0       0.0         0.0
#              2017        57                  0.0       0.0         6.0
#              2018        60                  0.0       0.0         6.0
#              2019        41                  0.0       0.0         0.0
#              2020        46                  0.0       0.0         6.0
#
#                    gr_Hispanic  gr_Hi_PacIsland  gr_White  gr_2orMore  \
# institute_id year
# 102845       2010          0.0              0.0       0.0         0.0
#              2011          0.0              0.0     149.0         6.0
#              2012         46.0              0.0     836.0        17.0
#              2013        149.0             25.0    2365.0        61.0
#              2014        692.0            112.0    1568.0       110.0
# ...                        ...              ...       ...         ...
# 488448       2016          0.0              0.0      24.0         0.0
#              2017          0.0              0.0      51.0         0.0
#              2018         18.0              0.0      36.0         0.0
#              2019         11.0              0.0      30.0         0.0
#              2020          0.0              0.0      40.0         0.0
#
#                    gr_unknown  gr_nonresAlien
# institute_id year
# 102845       2010         0.0             0.0
#              2011         0.0             6.0
#              2012        15.0             0.0
#              2013        46.0             0.0
#              2014       324.0             0.0
# ...                       ...             ...
# 488448       2016         0.0             0.0
#              2017         0.0             0.0
#              2018         0.0             0.0
#              2019         0.0             0.0
#              2020         0.0             0.0
#
# [660 rows x 10 columns]

# %%
df = pd.concat([df_enrollment, df_cohort], axis = 1)
df = pd.concat([df, df_cohort], axis = 1)

# %%
df.to_csv("C:\\project\\university_data_with_gradrate_and_cohort.csv")

# %%
df.shape
# Out:
# (766, 30)

# %%
df.info
# Out:
# <bound method DataFrame.info of                    e_total  e_AmerInd_AlaskNtv  e_Asian  e_AfrAmer  \
# institute_id year
# 102845       2010     1764                 121       47        111
#              2011     1651                  89       38         66
#              2012     1259                  67       76         62
#              2013     2191                  92       43         82
#              2014     3267                 132       40        198
# ...                    ...                 ...      ...        ...
# 488448       2016       71                   0        4          3
#              2017      113                   1        4          8
#              2018      100                   2        6         14
#              2019      106                   3        7         14
#              2020       96                   5        7          9
#
#                    e_Hispanic  e_Hi_PacIsland  e_White  e_2orMore  e_unknown  \
# institute_id year
# 102845       2010         455              40      693         19        178
#              2011         460              42      641         31        209
#              2012         401              19      525         64         45
#              2013         710             132      940        134         58
#              2014        1007             188     1430        142        130
# ...                       ...             ...      ...        ...        ...
# 488448       2016           7               0       57          0          0
#              2017           8               2       83          3          0
#              2018           3               1       67          2          0
#              2019          11               1       63          4          0
#              2020           8               0       62          5          0
#
#                    e_nonresAlien  ...  co_total  co_AmerInd_AlaskNtv  \
# institute_id year                 ...
# 102845       2010            100  ...    1658.0                109.0
#              2011             75  ...     871.0                 45.0
#              2012              0  ...     918.0                 54.0
#              2013              0  ...    1053.0                 49.0
#              2014              0  ...     437.0                 34.0
# ...                          ...  ...       ...                  ...
# 488448       2016              0  ...       6.0                  0.0
#              2017              4  ...       9.0                  0.0
#              2018              5  ...       7.0                  0.0
#              2019              3  ...       8.0                  0.0
#              2020              0  ...       9.0                  0.0
#
#                    co_Asian  co_AfrAmer  co_Hispanic  co_Hi_PacIsland  \
# institute_id year
# 102845       2010      40.0       102.0        440.0             39.0
#              2011      15.0        24.0        267.0             17.0
#              2012      63.0        42.0        282.0             10.0
#              2013      16.0        57.0        316.0             73.0
#              2014       3.0        25.0        156.0             25.0
# ...                     ...         ...          ...              ...
# 488448       2016       0.0         0.0          1.0              0.0
#              2017       0.0         1.0          1.0              0.0
#              2018       0.0         0.0          1.0              0.0
#              2019       0.0         1.0          2.0              0.0
#              2020       1.0         1.0          2.0              0.0
#
#                    co_White  co_2orMore  co_unknown  co_nonresAlien
# institute_id year
# 102845       2010     639.0        19.0       175.0            95.0
#              2011     323.0        16.0       124.0            40.0
#              2012     387.0        45.0        35.0             0.0
#              2013     451.0        68.0        23.0             0.0
#              2014     158.0        16.0        20.0             0.0
# ...                     ...         ...         ...             ...
# 488448       2016       5.0         0.0         0.0             0.0
#              2017       7.0         0.0         0.0             0.0
#              2018       6.0         0.0         0.0             0.0
#              2019       5.0         0.0         0.0             0.0
#              2020       5.0         0.0         0.0             0.0
#
# [766 rows x 30 columns]>
